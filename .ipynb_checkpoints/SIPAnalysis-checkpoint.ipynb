# %%
import pandas as pd

# %%
df = pd.read_csv('sample1.csv')

# %%
#PCAP Data File 1
df
# Out:
#        No.       Time        Source   Destination Protocol  Length  \
# 0        1   0.000000  200.57.7.195  200.57.7.204  SIP/SDP     740
# 1        2   0.007889  200.57.7.204  200.57.7.195      SIP     503
# 2        3   0.047524  200.57.7.204  200.57.7.195      SIP     504
# 3        4   0.049780  200.57.7.206  200.57.7.197      TCP      54
# 4        5   0.050802  200.57.7.197  200.57.7.206   TELNET     637
# ...    ...        ...           ...           ...      ...     ...
# 4264  4265  34.890149  200.57.7.204  200.57.7.194     HTTP     214
# 4265  4266  34.890418  200.57.7.194  200.57.7.204     HTTP      79
# 4266  4267  34.893607  200.57.7.194  200.57.7.197     SNMP     211
# 4267  4268  34.908251  200.57.7.199  200.57.7.196      UDP     214
# 4268  4269  34.908735  200.57.7.196  200.57.7.204      RTP     214
#
#                                                    Info
# 0     Request: INVITE sip:francisco@bestel.com:55060 |
# 1                                 Status: 100 Trying |
# 2                                Status: 180 Ringing |
# 3         1219  >  23 [ACK] Seq=1 Ack=1 Win=17465 Len=0
# 4                                       Telnet Data ...
# ...                                                 ...
# 4264  POST /cems/applets/serviceRouter HTTP/1.1  (ap...
# 4265                             HTTP/1.1 100 Continue
# 4266  get-request 1.3.6.1.4.1.2858.100.40.3.1.0 1.3....
# 4267                             4800  >  40378 Len=172
# 4268  PT=ITU-T G.711 PCMA, SSRC=0x58F33DEA, Seq=1222...
#
# [4269 rows x 7 columns]

# %%
#No of Packets file1
df.shape[0]
# Out:
# 4269

# %%
df1 = pd.read_csv('sample2.csv')

# %%
#PCAP Data File 2
df1
# Out:
#      No.         Time             Source       Destination Protocol  Length  \
# 0      1     0.000000        192.168.1.2     192.168.1.255     NBNS      92
# 1      2     0.746308        192.168.1.2     192.168.1.255     NBNS      92
# 2      3     1.497578        192.168.1.2     192.168.1.255     NBNS      92
# 3      4    10.816309   Silicom_01:6e:bd         Broadcast      ARP      42
# 4      5    10.816973  Castlene_00:34:56  Silicom_01:6e:bd      ARP      60
# ..   ...          ...                ...               ...      ...     ...
# 686  687  1553.571206        192.168.1.2       192.168.1.1      DNS      82
# 687  688  1553.572738        192.168.1.1       192.168.1.2      DNS     105
# 688  689  1553.574053        192.168.1.2     212.242.33.35      UDP      47
# 689  690  1565.594119        192.168.1.2       192.168.1.1      DNS      86
# 690  691  1566.588458        192.168.1.2       192.168.1.1      DNS      86
#
#                                                   Info
# 0                         Name query NB ECI_DOMAIN<1c>
# 1                         Name query NB ECI_DOMAIN<1c>
# 2                         Name query NB ECI_DOMAIN<1c>
# 3                Who has 192.168.1.1? Tell 192.168.1.2
# 4                  192.168.1.1 is at 00:30:54:00:34:56
# ..                                                 ...
# 686   Standard query 0x6336 PTR 1.0.0.127.in-addr.arpa
# 687  Standard query response 0x6336 PTR 1.0.0.127.i...
# 688                                5060  >  5060 Len=5
# 689  Standard query 0xf236 SRV _sip._udp.sip.cyberc...
# 690  Standard query 0xf236 SRV _sip._udp.sip.cyberc...
#
# [691 rows x 7 columns]

# %%
#No of Packets file2
df1.shape[0]
# Out:
# 691

# %%
#List only SIP Packets in File 1
sip = df[df['Protocol'] == 'SIP']
sip
# Out:
#        No.       Time        Source   Destination Protocol  Length  \
# 1        2   0.007889  200.57.7.204  200.57.7.195      SIP     503
# 2        3   0.047524  200.57.7.204  200.57.7.195      SIP     504
# 151    152   4.056633  200.57.7.205  200.57.7.195      SIP     460
# 152    153   4.072335  200.57.7.195  200.57.7.205      SIP     514
# 516    517   8.524137  200.57.7.195  200.57.7.204      SIP     485
# 1723  1724  17.457029  200.57.7.204  200.57.7.195      SIP     479
# 1726  1727  17.473413  200.57.7.195  200.57.7.204      SIP     532
# 2910  2911  24.309202  200.57.7.205  200.57.7.195      SIP     460
# 2911  2912  24.324792  200.57.7.195  200.57.7.205      SIP     514
# 2964  2965  24.674680  200.57.7.204  200.57.7.195      SIP     530
# 2966  2967  24.692752  200.57.7.204  200.57.7.195      SIP     531
#
#                                                   Info
# 1                                Status: 100 Trying |
# 2                               Status: 180 Ringing |
# 151    Request: REGISTER sip:Verso.com  (1 binding) |
# 152                     Status: 200 OK  (1 binding) |
# 516    Request: ACK sip:francisco@200.57.7.204:5061 |
# 1723  Request: REGISTER sip:bestel.com  (1 binding) |
# 1726                    Status: 200 OK  (1 binding) |
# 2910   Request: REGISTER sip:Verso.com  (1 binding) |
# 2911                    Status: 200 OK  (1 binding) |
# 2964                             Status: 100 Trying |
# 2966                            Status: 180 Ringing |

# %%
sip.shape
# Out:
# (11, 7)

# %%
#List only SIP Packets in File 1
sip1 = df1[df1['Protocol'] == 'SIP']
sip1
# Out:
#      No.         Time         Source    Destination Protocol  Length  \
# 18    19    32.004937    192.168.1.2  212.242.33.35      SIP     509
# 19    20    32.141694  212.242.33.35    192.168.1.2      SIP     528
# 29    30    49.420564    192.168.1.2  212.242.33.35      SIP     722
# 30    31    49.566655  212.242.33.35    192.168.1.2      SIP     348
# 31    32    49.616489  212.242.33.35    192.168.1.2      SIP     388
# ..   ...          ...            ...            ...      ...     ...
# 638  639  1460.423917    192.168.1.2  212.242.33.35      SIP     506
# 639  640  1460.565691  212.242.33.35    192.168.1.2      SIP     522
# 647  648  1477.884004    192.168.1.2  212.242.33.35      SIP     719
# 648  649  1478.031405  212.242.33.35    192.168.1.2      SIP     342
# 649  650  1478.042520  212.242.33.35    192.168.1.2      SIP     509
#
#                                                   Info
# 18   Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 19                         Status: 401 Unauthorized |
# 29   Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 30                               Status: 100 Trying |
# 31                       Status: 403 Wrong password |
# ..                                                 ...
# 638  Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 639                        Status: 401 Unauthorized |
# 647  Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 648                              Status: 100 Trying |
# 649                     Status: 200 OK  (1 binding) |
#
# [69 rows x 7 columns]

# %%
sip1.shape
# Out:
# (69, 7)

# %%
#List the SIP info fields wrt time
sip[['No.', 'Time', 'Info']]
# Out:
#        No.       Time                                              Info
# 1        2   0.007889                             Status: 100 Trying |
# 2        3   0.047524                            Status: 180 Ringing |
# 151    152   4.056633   Request: REGISTER sip:Verso.com  (1 binding) |
# 152    153   4.072335                    Status: 200 OK  (1 binding) |
# 516    517   8.524137   Request: ACK sip:francisco@200.57.7.204:5061 |
# 1723  1724  17.457029  Request: REGISTER sip:bestel.com  (1 binding) |
# 1726  1727  17.473413                    Status: 200 OK  (1 binding) |
# 2910  2911  24.309202   Request: REGISTER sip:Verso.com  (1 binding) |
# 2911  2912  24.324792                    Status: 200 OK  (1 binding) |
# 2964  2965  24.674680                             Status: 100 Trying |
# 2966  2967  24.692752                            Status: 180 Ringing |

# %%
#List the SIP info fields wrt time
sip1[['No.', 'Time', 'Info']]
# Out:
#      No.         Time                                               Info
# 18    19    32.004937  Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 19    20    32.141694                        Status: 401 Unauthorized |
# 29    30    49.420564  Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 30    31    49.566655                              Status: 100 Trying |
# 31    32    49.616489                      Status: 403 Wrong password |
# ..   ...          ...                                                ...
# 638  639  1460.423917  Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 639  640  1460.565691                        Status: 401 Unauthorized |
# 647  648  1477.884004  Request: REGISTER sip:sip.cybercity.dk  (1 bin...
# 648  649  1478.031405                              Status: 100 Trying |
# 649  650  1478.042520                     Status: 200 OK  (1 binding) |
#
# [69 rows x 3 columns]

# %%
#Analysis 1 File 1
infos = sip['Info'].to_list()
time = sip['Time'].to_list()

print('Type Fields\n')
flags = []
for info in infos:
    flag = info.split(':')
    flags.append(flag[0])
    print(flag[0])
# Out:
# Type Fields
#
# Status
# Status
# Request
# Status
# Request
# Request
# Status
# Request
# Status
# Status
# Status

# %%
#Analysis 1 File 2
infos1 = sip1['Info'].to_list()
time1 = sip1['Time'].to_list()

print('Type Fields\n')
flags1 = []
for info1 in infos1:
    flag1 = info1.split(':')
    flags1.append(flag1[0])
    print(flag1[0])
# Out:
# Type Fields
#
# Request
# Status
# Request
# Status
# Status
# Request
# Status
# Request
# Status
# Request
# Status
# Request
# Status
# Request
# Status
# Request
# Status
# Status
# Status
# Request
# Request
# Request
# Status
# Request
# Request
# Request
# Request
# Request
# Request
# Request
# Request
# Request
# Status
# Status
# Request
# Status
# Request
# Request
# Status
# Request
# Status
# Request
# Status
# Request
# Status
# Request
# Status
# Request
# Status
# Status
# Request
# Status
# Status
# Request
# Request
# Status
# Status
# Status
# Request
# Status
# Request
# Status
# Status
# Request
# Request
# Status
# Request
# Status
# Status

# %%
#Plot of Packets Length of SIP in File 1
# %matplotlib inline
df[df['Protocol']=='SIP'].Length.hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
#Plot of Packets Length of SIP in File 1
# %matplotlib inline
df1[df1['Protocol']=='SIP'].Length.hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
#Plot Type vs time interval for File1
plt.plot(time, flags)
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()

# %%
#Plot Type vs time interval for File2
plt.plot(time1, flags1)
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()
