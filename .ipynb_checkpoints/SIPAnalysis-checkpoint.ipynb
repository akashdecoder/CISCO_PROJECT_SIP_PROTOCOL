# %%
import pandas as pd

# %%
df = pd.read_csv('sample1.csv')

# %%
#PCAP Data File 1
df
# Out:
#        No.       Time         Source    Destination Protocol  Length  \
# 0        1   0.000000  192.168.10.41   192.168.10.2      SIP     596
# 1        2   0.000692   192.168.10.2  192.168.10.41      SIP     610
# 2        3   0.005771  192.168.10.41   192.168.10.2      SIP     755
# 3        4   0.009246   192.168.10.2  192.168.10.41      SIP     625
# 4        5   0.010308   192.168.10.2  192.168.10.41      SIP     654
# ...    ...        ...            ...            ...      ...     ...
# 1037  1038  32.400035  192.168.10.41   192.168.10.2      RTP     214
# 1038  1039  32.401915  192.168.10.41   192.168.10.2  SIP/SDP     942
# 1039  1040  32.402662   192.168.10.2  192.168.10.41      SIP     442
# 1040  1041  32.402739   192.168.10.2  192.168.10.41      SIP     480
# 1041  1042  32.490028  192.168.10.41   192.168.10.2      SIP     421
#
#                                                    Info
# 0     Request: REGISTER sip:192.168.10.2  (1 binding...
# 1                           Status: 401 Unauthorized |
# 2     Request: REGISTER sip:192.168.10.2  (1 binding...
# 3     Request: OPTIONS sip:10009@192.168.10.41:13434...
# 4                        Status: 200 OK  (1 binding) |
# ...                                                 ...
# 1037  PT=ITU-T G.711 PCMU, SSRC=0xBEE0F2ED, Seq=5307...
# 1038                                  Status: 200 OK |
# 1039      Request: ACK sip:10009@192.168.10.41:13434 |
# 1040      Request: BYE sip:10009@192.168.10.41:13434 |
# 1041                                  Status: 200 OK |
#
# [1042 rows x 7 columns]

# %%
#No of Packets file1
df.shape[0]
# Out:
# 1042

# %%
df1 = pd.read_csv('sample2.csv')

# %%
#PCAP Data File 2
df1
# Out:
#        No.       Time        Source   Destination Protocol  Length  \
# 0        1   0.000000  200.57.7.195  200.57.7.204  SIP/SDP     740
# 1        2   0.007889  200.57.7.204  200.57.7.195      SIP     503
# 2        3   0.047524  200.57.7.204  200.57.7.195      SIP     504
# 3        4   0.049780  200.57.7.206  200.57.7.197      TCP      54
# 4        5   0.050802  200.57.7.197  200.57.7.206   TELNET     637
# ...    ...        ...           ...           ...      ...     ...
# 4264  4265  34.890149  200.57.7.204  200.57.7.194     HTTP     214
# 4265  4266  34.890418  200.57.7.194  200.57.7.204     HTTP      79
# 4266  4267  34.893607  200.57.7.194  200.57.7.197     SNMP     211
# 4267  4268  34.908251  200.57.7.199  200.57.7.196      UDP     214
# 4268  4269  34.908735  200.57.7.196  200.57.7.204      RTP     214
#
#                                                    Info
# 0     Request: INVITE sip:francisco@bestel.com:55060 |
# 1                                 Status: 100 Trying |
# 2                                Status: 180 Ringing |
# 3         1219  >  23 [ACK] Seq=1 Ack=1 Win=17465 Len=0
# 4                                       Telnet Data ...
# ...                                                 ...
# 4264  POST /cems/applets/serviceRouter HTTP/1.1  (ap...
# 4265                             HTTP/1.1 100 Continue
# 4266  get-request 1.3.6.1.4.1.2858.100.40.3.1.0 1.3....
# 4267                             4800  >  40378 Len=172
# 4268  PT=ITU-T G.711 PCMA, SSRC=0x58F33DEA, Seq=1222...
#
# [4269 rows x 7 columns]

# %%
#No of Packets file2
df1.shape[0]
# Out:
# 4269

# %%
df2 = pd.read_csv('sample3.csv')

# %%
#PCAP Data File 3
df2
# Out:
#        No.        Time           Source      Destination Protocol  Length  \
# 0        1    0.000000  192.168.105.110  192.168.105.105      SIP     596
# 1        2    0.000639  192.168.105.105  192.168.105.110      SIP     362
# 2        3    0.032186  192.168.105.105  192.168.105.110      SIP     456
# 3        4   10.000441  192.168.105.110  192.168.105.105      SIP     597
# 4        5   10.001733  192.168.105.105  192.168.105.110      SIP     363
# ...    ...         ...              ...              ...      ...     ...
# 1355  1356   96.809551  192.168.105.110  192.168.105.172      RTP     294
# 1356  1357   96.829533  192.168.105.172  192.168.105.110      RTP     294
# 1357  1358  100.005644  192.168.105.110  192.168.105.105      SIP     597
# 1358  1359  100.006096  192.168.105.105  192.168.105.110      SIP     363
# 1359  1360  100.036779  192.168.105.105  192.168.105.110      SIP     457
#
#                                                    Info
# 0     Request: REGISTER sip:192.168.105.105  (1 bind...
# 1                                 Status: 100 Trying |
# 2                        Status: 200 OK  (1 binding) |
# 3     Request: REGISTER sip:192.168.105.105  (1 bind...
# 4                                 Status: 100 Trying |
# ...                                                 ...
# 1355  PT=ITU-T G.711 PCMA, SSRC=0x9A7B5382, Seq=5339...
# 1356  PT=ITU-T G.711 PCMA, SSRC=0x5711BF84, Seq=6318...
# 1357  Request: REGISTER sip:192.168.105.105  (1 bind...
# 1358                              Status: 100 Trying |
# 1359                     Status: 200 OK  (1 binding) |
#
# [1360 rows x 7 columns]

# %%
#No of Packets file3
df2.shape[0]
# Out:
# 1360

# %%
#List only SIP Packets in File 1
sip = df[df['Protocol'] == 'SIP']
sip
# Out:
#        No.       Time         Source    Destination Protocol  Length  \
# 0        1   0.000000  192.168.10.41   192.168.10.2      SIP     596
# 1        2   0.000692   192.168.10.2  192.168.10.41      SIP     610
# 2        3   0.005771  192.168.10.41   192.168.10.2      SIP     755
# 3        4   0.009246   192.168.10.2  192.168.10.41      SIP     625
# 4        5   0.010308   192.168.10.2  192.168.10.41      SIP     654
# 5        6   0.017462  192.168.10.41   192.168.10.2      SIP     593
# 6        7   0.024945  192.168.10.41   192.168.10.2      SIP     600
# 7        8   0.028999   192.168.10.2  192.168.10.41      SIP     611
# 8        9   0.032569  192.168.10.41   192.168.10.2      SIP     664
# 9       10   0.033144   192.168.10.2  192.168.10.41      SIP     599
# 10      11   0.043205  192.168.10.41   192.168.10.2      SIP     765
# 11      12   0.043782   192.168.10.2  192.168.10.41      SIP     528
# 12      13   0.047481  192.168.10.41   192.168.10.2      SIP     829
# 13      14   0.047988   192.168.10.2  192.168.10.41      SIP     516
# 15      16   8.778390   192.168.10.2  192.168.10.41      SIP     608
# 16      17   8.779575  192.168.10.41   192.168.10.2      SIP     394
# 18      19   8.784732   192.168.10.2  192.168.10.41      SIP     542
# 19      20   8.807730   192.168.10.2  192.168.10.41      SIP     558
# 26      27  16.477819  192.168.10.41   192.168.10.2      SIP     647
# 1039  1040  32.402662   192.168.10.2  192.168.10.41      SIP     442
# 1040  1041  32.402739   192.168.10.2  192.168.10.41      SIP     480
# 1041  1042  32.490028  192.168.10.41   192.168.10.2      SIP     421
#
#                                                    Info
# 0     Request: REGISTER sip:192.168.10.2  (1 binding...
# 1                           Status: 401 Unauthorized |
# 2     Request: REGISTER sip:192.168.10.2  (1 binding...
# 3     Request: OPTIONS sip:10009@192.168.10.41:13434...
# 4                        Status: 200 OK  (1 binding) |
# 5                                     Status: 200 OK |
# 6          Request: SUBSCRIBE sip:10009@192.168.10.2 |
# 7                           Status: 401 Unauthorized |
# 8          Request: SUBSCRIBE sip:10008@192.168.10.2 |
# 9                           Status: 401 Unauthorized |
# 10         Request: SUBSCRIBE sip:10009@192.168.10.2 |
# 11                             Status: 404 Not Found |
# 12         Request: SUBSCRIBE sip:10008@192.168.10.2 |
# 13                             Status: 404 Not Found |
# 15                          Status: 401 Unauthorized |
# 16               Request: ACK sip:10008@192.168.10.2 |
# 18                                Status: 100 Trying |
# 19                               Status: 180 Ringing |
# 26               Request: ACK sip:10008@192.168.10.2 |
# 1039      Request: ACK sip:10009@192.168.10.41:13434 |
# 1040      Request: BYE sip:10009@192.168.10.41:13434 |
# 1041                                  Status: 200 OK |

# %%
sip.shape
# Out:
# (22, 7)

# %%
#List only SIP Packets in File 1
sip1 = df1[df1['Protocol'] == 'SIP']
sip1
# Out:
#        No.       Time        Source   Destination Protocol  Length  \
# 1        2   0.007889  200.57.7.204  200.57.7.195      SIP     503
# 2        3   0.047524  200.57.7.204  200.57.7.195      SIP     504
# 151    152   4.056633  200.57.7.205  200.57.7.195      SIP     460
# 152    153   4.072335  200.57.7.195  200.57.7.205      SIP     514
# 516    517   8.524137  200.57.7.195  200.57.7.204      SIP     485
# 1723  1724  17.457029  200.57.7.204  200.57.7.195      SIP     479
# 1726  1727  17.473413  200.57.7.195  200.57.7.204      SIP     532
# 2910  2911  24.309202  200.57.7.205  200.57.7.195      SIP     460
# 2911  2912  24.324792  200.57.7.195  200.57.7.205      SIP     514
# 2964  2965  24.674680  200.57.7.204  200.57.7.195      SIP     530
# 2966  2967  24.692752  200.57.7.204  200.57.7.195      SIP     531
#
#                                                   Info
# 1                                Status: 100 Trying |
# 2                               Status: 180 Ringing |
# 151    Request: REGISTER sip:Verso.com  (1 binding) |
# 152                     Status: 200 OK  (1 binding) |
# 516    Request: ACK sip:francisco@200.57.7.204:5061 |
# 1723  Request: REGISTER sip:bestel.com  (1 binding) |
# 1726                    Status: 200 OK  (1 binding) |
# 2910   Request: REGISTER sip:Verso.com  (1 binding) |
# 2911                    Status: 200 OK  (1 binding) |
# 2964                             Status: 100 Trying |
# 2966                            Status: 180 Ringing |

# %%
sip1.shape
# Out:
# (11, 7)

# %%
#List only SIP Packets in File 3
sip2 = df2[df2['Protocol'] == 'SIP']
sip2
# Out:
#        No.        Time           Source      Destination Protocol  Length  \
# 0        1    0.000000  192.168.105.110  192.168.105.105      SIP     596
# 1        2    0.000639  192.168.105.105  192.168.105.110      SIP     362
# 2        3    0.032186  192.168.105.105  192.168.105.110      SIP     456
# 3        4   10.000441  192.168.105.110  192.168.105.105      SIP     597
# 4        5   10.001733  192.168.105.105  192.168.105.110      SIP     363
# 5        6   10.033344  192.168.105.105  192.168.105.110      SIP     457
# 6        7   36.002756  192.168.105.110  192.168.105.105      SIP     570
# 7        8   36.003190  192.168.105.105  192.168.105.110      SIP     355
# 8        9   36.019858  192.168.105.105  192.168.105.110      SIP     386
# 9       10   36.024706  192.168.105.110  192.168.105.105      SIP     437
# 10      11   40.002985  192.168.105.110  192.168.105.105      SIP     596
# 11      12   40.003476  192.168.105.105  192.168.105.110      SIP     362
# 12      13   40.034723  192.168.105.105  192.168.105.110      SIP     454
# 13      14   52.003970  192.168.105.110  192.168.105.105      SIP     572
# 14      15   52.004399  192.168.105.105  192.168.105.110      SIP     357
# 15      16   52.033792  192.168.105.105  192.168.105.110      SIP     658
# 16      17   52.041339  192.168.105.110  192.168.105.105      SIP     513
# 17      18   53.102765  192.168.105.110  192.168.105.105      SIP     625
# 18      19   53.110754  192.168.105.105  192.168.105.110      SIP     551
# 23      24   70.003917  192.168.105.110  192.168.105.105      SIP     596
# 24      25   70.004412  192.168.105.105  192.168.105.110      SIP     362
# 25      26   70.035666  192.168.105.105  192.168.105.110      SIP     454
# 1357  1358  100.005644  192.168.105.110  192.168.105.105      SIP     597
# 1358  1359  100.006096  192.168.105.105  192.168.105.110      SIP     363
# 1359  1360  100.036779  192.168.105.105  192.168.105.110      SIP     457
#
#                                                    Info
# 0     Request: REGISTER sip:192.168.105.105  (1 bind...
# 1                                 Status: 100 Trying |
# 2                        Status: 200 OK  (1 binding) |
# 3     Request: REGISTER sip:192.168.105.105  (1 bind...
# 4                                 Status: 100 Trying |
# 5                        Status: 200 OK  (1 binding) |
# 6           Request: INVITE sip:2504@192.168.105.105 |
# 7                                 Status: 100 Trying |
# 8                                Status: 603 Decline |
# 9              Request: ACK sip:2504@192.168.105.105 |
# 10    Request: REGISTER sip:192.168.105.105  (1 bind...
# 11                                Status: 100 Trying |
# 12                       Status: 200 OK  (1 binding) |
# 13          Request: INVITE sip:2504@192.168.105.105 |
# 14                                Status: 100 Trying |
# 15     Request: INVITE sip:2504@192.168.105.110:5060 |
# 16                                Status: 100 Trying |
# 17                               Status: 180 Ringing |
# 18                               Status: 180 Ringing |
# 23    Request: REGISTER sip:192.168.105.105  (1 bind...
# 24                                Status: 100 Trying |
# 25                       Status: 200 OK  (1 binding) |
# 1357  Request: REGISTER sip:192.168.105.105  (1 bind...
# 1358                              Status: 100 Trying |
# 1359                     Status: 200 OK  (1 binding) |

# %%
sip2.shape
# Out:
# (25, 7)

# %%
#List the SIP info fields wrt time for file 1
sip[['No.', 'Time', 'Info']]
# Out:
#        No.       Time                                               Info
# 0        1   0.000000  Request: REGISTER sip:192.168.10.2  (1 binding...
# 1        2   0.000692                        Status: 401 Unauthorized |
# 2        3   0.005771  Request: REGISTER sip:192.168.10.2  (1 binding...
# 3        4   0.009246  Request: OPTIONS sip:10009@192.168.10.41:13434...
# 4        5   0.010308                     Status: 200 OK  (1 binding) |
# 5        6   0.017462                                  Status: 200 OK |
# 6        7   0.024945       Request: SUBSCRIBE sip:10009@192.168.10.2 |
# 7        8   0.028999                        Status: 401 Unauthorized |
# 8        9   0.032569       Request: SUBSCRIBE sip:10008@192.168.10.2 |
# 9       10   0.033144                        Status: 401 Unauthorized |
# 10      11   0.043205       Request: SUBSCRIBE sip:10009@192.168.10.2 |
# 11      12   0.043782                           Status: 404 Not Found |
# 12      13   0.047481       Request: SUBSCRIBE sip:10008@192.168.10.2 |
# 13      14   0.047988                           Status: 404 Not Found |
# 15      16   8.778390                        Status: 401 Unauthorized |
# 16      17   8.779575             Request: ACK sip:10008@192.168.10.2 |
# 18      19   8.784732                              Status: 100 Trying |
# 19      20   8.807730                             Status: 180 Ringing |
# 26      27  16.477819             Request: ACK sip:10008@192.168.10.2 |
# 1039  1040  32.402662      Request: ACK sip:10009@192.168.10.41:13434 |
# 1040  1041  32.402739      Request: BYE sip:10009@192.168.10.41:13434 |
# 1041  1042  32.490028                                  Status: 200 OK |

# %%
#List the SIP info fields wrt time for file 3
sip1[['No.', 'Time', 'Info']]
# Out:
#        No.       Time                                              Info
# 1        2   0.007889                             Status: 100 Trying |
# 2        3   0.047524                            Status: 180 Ringing |
# 151    152   4.056633   Request: REGISTER sip:Verso.com  (1 binding) |
# 152    153   4.072335                    Status: 200 OK  (1 binding) |
# 516    517   8.524137   Request: ACK sip:francisco@200.57.7.204:5061 |
# 1723  1724  17.457029  Request: REGISTER sip:bestel.com  (1 binding) |
# 1726  1727  17.473413                    Status: 200 OK  (1 binding) |
# 2910  2911  24.309202   Request: REGISTER sip:Verso.com  (1 binding) |
# 2911  2912  24.324792                    Status: 200 OK  (1 binding) |
# 2964  2965  24.674680                             Status: 100 Trying |
# 2966  2967  24.692752                            Status: 180 Ringing |

# %%
#List the SIP info fields wrt time for file 3
sip2[['No.', 'Time', 'Info']]
# Out:
#        No.        Time                                               Info
# 0        1    0.000000  Request: REGISTER sip:192.168.105.105  (1 bind...
# 1        2    0.000639                              Status: 100 Trying |
# 2        3    0.032186                     Status: 200 OK  (1 binding) |
# 3        4   10.000441  Request: REGISTER sip:192.168.105.105  (1 bind...
# 4        5   10.001733                              Status: 100 Trying |
# 5        6   10.033344                     Status: 200 OK  (1 binding) |
# 6        7   36.002756        Request: INVITE sip:2504@192.168.105.105 |
# 7        8   36.003190                              Status: 100 Trying |
# 8        9   36.019858                             Status: 603 Decline |
# 9       10   36.024706           Request: ACK sip:2504@192.168.105.105 |
# 10      11   40.002985  Request: REGISTER sip:192.168.105.105  (1 bind...
# 11      12   40.003476                              Status: 100 Trying |
# 12      13   40.034723                     Status: 200 OK  (1 binding) |
# 13      14   52.003970        Request: INVITE sip:2504@192.168.105.105 |
# 14      15   52.004399                              Status: 100 Trying |
# 15      16   52.033792   Request: INVITE sip:2504@192.168.105.110:5060 |
# 16      17   52.041339                              Status: 100 Trying |
# 17      18   53.102765                             Status: 180 Ringing |
# 18      19   53.110754                             Status: 180 Ringing |
# 23      24   70.003917  Request: REGISTER sip:192.168.105.105  (1 bind...
# 24      25   70.004412                              Status: 100 Trying |
# 25      26   70.035666                     Status: 200 OK  (1 binding) |
# 1357  1358  100.005644  Request: REGISTER sip:192.168.105.105  (1 bind...
# 1358  1359  100.006096                              Status: 100 Trying |
# 1359  1360  100.036779                     Status: 200 OK  (1 binding) |

# %%
#Analysis 1 File 1
infos = sip['Info'].to_list()
times = sip['Time'].to_list()
print('Type Fields\n')
flags = []
print('Time\t\t\tType\t\t\tCommand\n')
for info, times in zip(infos, times):
    flag = info.split(':')
    command = flag[1].split(' ')
    if(command[1].isdigit()):
        command1 = flag[1].strip().split(' ', 2)
        command = command1[1]
        print(time, '\t\t', flag[0] ,'\t\t', command)
    else:
        command = flag[1].strip().split(' ', 1)
        print(time, '\t\t', flag[0] ,'\t\t', command[0])
    flags.append(flag[0])
# Out:
# Type Fields
#
# Time			Type			Command
#
# 0.0 		 Request 		 REGISTER
# 0.000692 		 Status 		 Unauthorized
# 0.005771 		 Request 		 REGISTER
# 0.009246 		 Request 		 OPTIONS
# 0.010308 		 Status 		 OK
# 0.017462 		 Status 		 OK
# 0.024945 		 Request 		 SUBSCRIBE
# 0.028999 		 Status 		 Unauthorized
# 0.032569 		 Request 		 SUBSCRIBE
# 0.033144 		 Status 		 Unauthorized
# 0.043205 		 Request 		 SUBSCRIBE
# 0.043782 		 Status 		 Not
# 0.047481 		 Request 		 SUBSCRIBE
# 0.047988 		 Status 		 Not
# 8.77839 		 Status 		 Unauthorized
# 8.779575 		 Request 		 ACK
# 8.784732 		 Status 		 Trying
# 8.80773 		 Status 		 Ringing
# 16.477819 		 Request 		 ACK
# 32.402662 		 Request 		 ACK
# 32.402739 		 Request 		 BYE
# 32.490028 		 Status 		 OK

# %%
#Analysis 1 File 2
infos1 = sip1['Info'].to_list()
times1 = sip1['Time'].to_list()

print('Type Fields\n')
flags1 = []
print('Time\t\t\tType\t\t\t Command\n')
for info1, time1 in zip(infos1, times1):
    flag1 = info1.split(':')
    command1 = flag1[1].split(' ')
    if(command1[1].isdigit()):
        command2 = flag1[1].strip().split(' ', 2)
        command1 = command2[1]
        print(time1, '\t\t' ,flag1[0] ,'\t\t', command1)
    else:
        command1 = flag1[1].strip().split(' ', 1)
        print(time1, '\t\t' ,flag1[0] ,'\t\t', command1[0])
    flags1.append(flag1[0])
# Out:
# Type Fields
#
# Time			Type			 Command
#
# 0.007889 		 Status 		 Trying
# 0.047524 		 Status 		 Ringing
# 4.056633 		 Request 		 REGISTER
# 4.072335 		 Status 		 OK
# 8.524137 		 Request 		 ACK
# 17.457029 		 Request 		 REGISTER
# 17.473413 		 Status 		 OK
# 24.309202 		 Request 		 REGISTER
# 24.324792 		 Status 		 OK
# 24.67468 		 Status 		 Trying
# 24.692752 		 Status 		 Ringing

# %%
#Analysis 1 File 1
infos2 = sip2['Info'].to_list()
times2 = sip2['Time'].to_list()

print('Type Fields\n')
flags2 = []
print('Time\t\t\tType\t\t\tCommand\n')
for info2, time2 in zip(infos2, times2):
    flag2 = info2.split(':')
    command2 = flag2[1].split(' ')
    if(command2[1].isdigit()):
        command3 = flag[1].strip().split(' ', 2)
        command2 = command3[1]
        print(time2, '\t\t', flag[0] ,'\t\t', command2)
    else:
        command2 = flag2[1].strip().split(' ', 1)
        print(time2, '\t\t', flag2[0] ,'\t\t', command2[0])
    flags2.append(flag2[0])
# Out:
# Type Fields
#
# Time			Type			Command
#
# 0.0 		 Request 		 REGISTER
# 0.000639 		 Status 		 OK
# 0.032186 		 Status 		 OK
# 10.000441 		 Request 		 REGISTER
# 10.001733 		 Status 		 OK
# 10.033344 		 Status 		 OK
# 36.002756 		 Request 		 INVITE
# 36.00319 		 Status 		 OK
# 36.019858 		 Status 		 OK
# 36.024706 		 Request 		 ACK
# 40.002985 		 Request 		 REGISTER
# 40.003476 		 Status 		 OK
# 40.034723 		 Status 		 OK
# 52.00397 		 Request 		 INVITE
# 52.004399 		 Status 		 OK
# 52.033792 		 Request 		 INVITE
# 52.041339 		 Status 		 OK
# 53.102765 		 Status 		 OK
# 53.110754 		 Status 		 OK
# 70.003917 		 Request 		 REGISTER
# 70.004412 		 Status 		 OK
# 70.035666 		 Status 		 OK
# 100.005644 		 Request 		 REGISTER
# 100.006096 		 Status 		 OK
# 100.036779 		 Status 		 OK

# %%
#Plot of Packets Length of SIP in File 1
# %matplotlib inline
df[df['Protocol']=='SIP'].Length.hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
#Plot of Packets Length of SIP in File 2
# %matplotlib inline
df1[df1['Protocol']=='SIP'].Length.hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
#Plot of Packets Length of SIP in File 3
# %matplotlib inline
df2[df2['Protocol']=='SIP'].Length.hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
#Plot Type vs time interval for File1
plt.plot(time, flags)
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()

# %%
#Plot Information vs time interval for File1
plt.plot(time, infos)
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()

# %%
#Plot Type vs time interval for File2
plt.plot(time1, flags1, color='darkorange')
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()

# %%
#Plot Information vs time interval for File2
plt.plot(time1, infos1)
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()

# %%
#Plot Type vs time interval for File3
plt.plot(time2, flags2, color='green')
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()

# %%
#Plot Information vs time interval for File3
plt.plot(time2, infos2)
plt.xlabel('Time Interval')
plt.ylabel('Type')
plt.title('SIP Analysis')
plt.show()

# %%
plt.plot(time, flags, label='pcap plot')
plt.plot(time1, flags1, label='pcap1 plot')
plt.plot(time2, flags2, label='pcap2 plot')
plt.xlabel('Time Interval')
plt.ylabel('Flag')
plt.title('SIP Analysis')
plt.legend()
